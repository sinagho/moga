# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.functional as F
import torch.optim as optim

# %%
from lhunet.modules.cnn.attentions import DLKA3D_Block_onTensor
from lhunet.models.v12 import LHUNet

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
block = DLKA3D_Block_onTensor(64).to(device)
block.train()

criteria = nn.MSELoss().to(device).to(torch.float16)
optimizer = optim.Adam(block.parameters(), lr=0.001)

x = torch.randn(1, 64, 32, 32, 32).to(device)
y = torch.randn(1, 64, 32, 32, 32).to(device)


# optimizer.zero_grad()
# outputs = block(x)
# print(outputs.size())

# loss = criteria(outputs, y)
# print(loss.item())
# loss.backward()

# %%
torch.__version__
# Out:
# '2.5.1+cu124'

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
block = DLKA3D_Block_onTensor(64).to(device)
block.train()

criteria = nn.MSELoss().to(device).to(torch.float16)
optimizer = optim.Adam(block.parameters(), lr=0.001)

x = torch.randn(1, 64, 32, 32, 32).to(device)
y = torch.randn(1, 64, 32, 32, 32).to(device)

scaler = torch.amp.GradScaler()
optimizer.zero_grad()

with torch.autocast(device_type="cuda", dtype=torch.float16):
    output = block(x)
    loss = criteria(output, y)

scaler.scale(loss).backward()
scaler.step(optimizer)
scaler.update()

# %%
scaler = torch.cuda.amp.GradScaler()

for input, target in dataloader:
    optimizer.zero_grad()

    # Forward pass inside autocast
    with torch.cuda.amp.autocast():
        output = model(input)
        loss = criterion(output, target)

    # Backward pass with scaler
    scaler.scale(loss).backward()
    scaler.step(optimizer)
    scaler.update()
# Out:
# `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 scaler = torch.cuda.amp.GradScaler()
# ----> 3 for input, target in dataloader:
#       4     optimizer.zero_grad()
#       6     # Forward pass inside autocast
#
# NameError: name 'dataloader' is not defined

# %%
# device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# block=LHUNet(
#             spatial_shapes= [64,128,128],
#             in_channels=1,
#             out_channels=13,
#             do_ds=False,
#             # encoder params
#             cnn_kernel_sizes=[3, 3],
#             cnn_features=[12, 16],
#             cnn_strides=[[1, 2, 2], 2],
#             cnn_maxpools=[True, True],
#             cnn_dropouts=0.0,
#             cnn_blocks="nn",  # n= resunet, d= deformconv, b= basicunet,
#             hyb_kernel_sizes=[3, 3, 3],
#             hyb_features=[32, 64, 128],
#             hyb_strides=[2, 2, 2],
#             hyb_maxpools=[True, True, True],
#             hyb_cnn_dropouts=0.0,
#             hyb_tf_proj_sizes=[64, 32, 0],
#             hyb_tf_repeats=[1, 1, 1],
#             hyb_tf_num_heads=[8,8,16],
#             hyb_tf_dropouts=0.1,
#             hyb_cnn_blocks="nnn",  # n= resunet, d= deformconv, b= basicunet,
#             hyb_vit_blocks="SSC",  # s= dlka_special_v2, S= dlka_sp_seq, c= dlka_channel_v2, C= dlka_ch_seq,
#             # hyb_vit_sandwich= False,
#             hyb_skip_mode="cat",  # "sum" or "cat",
#             hyb_arch_mode="residual",  # sequential, residual, parallel, collective,
#             hyb_res_mode="sum",  # "sum" or "cat",
#             # decoder params
#             dec_hyb_tcv_kernel_sizes=[5, 5, 5],
#             dec_cnn_tcv_kernel_sizes=[5, 7],
#             dec_cnn_blocks=None,
#             dec_tcv_bias=False,
#             dec_hyb_tcv_bias=False,
#             dec_hyb_kernel_sizes=None,
#             dec_hyb_features=None,
#             dec_hyb_cnn_dropouts=None,
#             dec_hyb_tf_proj_sizes=None,
#             dec_hyb_tf_repeats=None,
#             dec_hyb_tf_num_heads=None,
#             dec_hyb_tf_dropouts=None,
#             dec_cnn_kernel_sizes=None,
#             dec_cnn_features=None,
#             dec_cnn_dropouts=None,
#             dec_hyb_cnn_blocks=None,
#             dec_hyb_vit_blocks=None,
#             # dec_hyb_vit_sandwich= None,
#             dec_hyb_skip_mode=None,
#             dec_hyb_arch_mode="collective",  # sequential, residual, parallel, collective, sequential-lite,
#             dec_hyb_res_mode=None,
#         ).to(device)

# block.train()

# criteria = nn.MSELoss()
# optimizer = optim.Adam(block.parameters(), lr=0.001)

# x = torch.randn(1, 1, 64, 128, 128).to(device).to(torch.float16)
# y = torch.randn(1, 13, 64, 128, 128).to(device).to(torch.float16)


# # optimizer.zero_grad()
# # outputs = block(x)
# # print(outputs.size())

# # loss = criteria(outputs, y)
# # print(loss.item())
# # loss.backward()

# %%
scaler = torch.cuda.amp.GradScaler()

with torch.cuda.amp.autocast():
    optimizer.zero_grad()
    outputs = block(x)
    loss = criteria(outputs, y)
loss.backward()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[6], line 7
#       5     outputs = block(x)
#       6     loss = criteria(outputs, y)
# ----> 7 loss.backward()
#
# File /scratch/.venvs/pytorch/lib/python3.10/site-packages/torch/_tensor.py:492, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     482 if has_torch_function_unary(self):
#     483     return handle_torch_function(
#     484         Tensor.backward,
#     485         (self,),
#    (...)
#     490         inputs=inputs,
#     491     )
# --> 492 torch.autograd.backward(
#     493     self, gradient, retain_graph, create_graph, inputs=inputs
#     494 )
#
# File /scratch/.venvs/pytorch/lib/python3.10/site-packages/torch/autograd/__init__.py:251, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     246     retain_graph = create_graph
#     248 # The reason we repeat the same comment below is that
#     249 # some Python versions print out the first line of a multi-line function
#     250 # calls in the traceback and some print out the last line
# --> 251 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     252     tensors,
#     253     grad_tensors_,
#     254     retain_graph,
#     255     create_graph,
#     256     inputs,
#     257     allow_unreachable=True,
#     258     accumulate_grad=True,
#     259 )
#
# File /scratch/.venvs/pytorch/lib/python3.10/site-packages/torch/autograd/function.py:288, in BackwardCFunction.apply(self, *args)
#     282     raise RuntimeError(
#     283         "Implementing both 'backward' and 'vjp' for a custom "
#     284         "Function is not allowed. You should only implement one "
#     285         "of them."
#     286     )
#     287 user_fn = vjp_fn if vjp_fn is not Function.vjp else backward_fn
# --> 288 return user_fn(self, *args)
#
# File /scratch/.venvs/pytorch/lib/python3.10/site-packages/torch/autograd/function.py:556, in once_differentiable.<locals>.wrapper(ctx, *args)
#     553 @functools.wraps(fn)
#     554 def wrapper(ctx, *args):
#     555     with torch.no_grad():
# --> 556         outputs = fn(ctx, *args)
#     558     if not torch.is_grad_enabled():
#     559         return outputs
#
# File /scratch/deeplearning/moga/lhunet/modules/deform_conv.py:69, in DeformConvFunction.backward(ctx, grad_output)
#      65 @staticmethod
#      66 @once_differentiable
#      67 def backward(ctx, grad_output):
#      68     input, offset, weight, bias = ctx.saved_tensors
# ---> 69     grad_input, grad_offset, grad_weight, grad_bias = D3D.deform_conv_backward(
#      70         input,
#      71         weight,
#      72         bias,
#      73         offset,
#      74         grad_output,
#      75         ctx.kernel_size[0],
#      76         ctx.kernel_size[1],
#      77         ctx.kernel_size[2],
#      78         ctx.stride[0],
#      79         ctx.stride[1],
#      80         ctx.stride[2],
#      81         ctx.padding[0],
#      82         ctx.padding[1],
#      83         ctx.padding[2],
#      84         ctx.dilation[0],
#      85         ctx.dilation[1],
#      86         ctx.dilation[2],
#      87         ctx.group,
#      88         ctx.deformable_groups,
#      89         ctx.im2col_step,
#      90     )
#      92     return (
#      93         grad_input,
#      94         grad_offset,
#    (...)
#     102         None,
#     103     )
#
# RuntimeError: expected mat1 and mat2 to have the same dtype, but got: float != c10::Half
